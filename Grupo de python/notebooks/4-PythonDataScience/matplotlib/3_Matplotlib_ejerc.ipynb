# %% [markdown]
# # **Ejercicios Matplotlib**
# Resuelve los siguientes ejercicios utilzando únicamente Matplotlib y Numpy. En  caso  que no se especifique el conjunto de datos a graficar, deberás crear los rangos.

# %% [markdown]
# 1. Crea una gráfica de línea tomando los valores del eje x y y de un archivo de texto. Lee los valores con `numpy`. Copia y pega el siguiente texto en nuevo archivo de texto:
# ~~~~
# 1 2
# 2 4
# 3 1
# 4 6
# 5 20
# 6 4
# 7 8
# 8 16
# 9 10
# 10 7
# ~~~~

# %%
import numpy as np

# montamos la unidad de drive en colab
from google.colab import drive
drive.mount('/content/gdrive')

data_path= 'gdrive/My Drive/Colab Notebooks/datasets/ejercMatplotlib.csv'
arreglo=np.genfromtxt(data_path, delimiter=",", skip_header=1)
arreglo
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# array([[ 1.,  2.],
#        [ 2.,  4.],
#        [ 3.,  1.],
#        [ 4.,  6.],
#        [ 5., 20.],
#        [ 6.,  4.],
#        [ 7.,  8.],
#        [ 8., 16.],
#        [ 9., 10.],
#        [10.,  7.]])

# %%
import matplotlib.pyplot as plt

plt.plot(arreglo[:,0],arreglo[:,1])

# %% [markdown]
# 2. Utiliza los siguientes datos para replicar la siguiente gráfica:
# ### Datos:
# **Date**|**Open**|**High**|**Low**|**Close**
# :-----:|:-----:|:-----:|:-----:|:-----:
# 10-03-16|774.25|776.065002|769.5|772.559998
# 10-04-16|776.030029|778.710022|772.890015|776.429993
# 10-05-16|779.309998|782.070007|775.650024|776.469971
# 10-06-16|779|780.47998|775.539978|776.859985
# 10-07-16|779.659973|779.659973|770.75|775.080017
#
#
#
# ### Gráfica:
#
# <img
#   src="https://raw.githubusercontent.com/albreyes/python/main/Grupo%20de%20python/notebooks/4-PythonDataScience/matplotlib/grafica_ejercicio_2.png"
#   alt="La cabeza y el torso de un esqueleto de dinosaurio;
#            tiene una cabeza grande con dientes largos y afilados"
#   width="400"
#   height="341" />

# %%
data_path1= 'gdrive/My Drive/Colab Notebooks/datasets/ejerc2Matplotlib.csv'
arreglo1=np.genfromtxt(data_path1, delimiter=",", skip_header=1)
arreglo1
fig, ax=plt.subplots()

ax.plot(arreglo1[:,1],label="Open")
ax.plot(arreglo1[:,2],label="High")
ax.plot(arreglo1[:,3],label="Low")
ax.plot(arreglo1[:,4],label="Close")
ax.legend()

# %% [markdown]
# 3. Crea una gráfica que contenga dos líneas de diferente color con una leyenda apropiada a cada línea
#
# <img
#   src="https://raw.githubusercontent.com/albreyes/python/d70737a223c6ce342ca2eafc2349d874d1e882b2/Grupo%20de%20python/notebooks/4-PythonDataScience/matplotlib/grafica_ejercicio_3.png"
#   alt="La cabeza y el torso de un esqueleto de dinosaurio;
#            tiene una cabeza grande con dientes largos y afilados"
#   width="400"
#   height="341" />

# %%
x1=[10,20,30]
y1=[20,40,10]
x2=[10,20,30]
y2=[40,10,30]

fig, ax= plt.subplots()
ax.plot(x1,y1,"b-")
ax.plot(x2,y2,"g-")

# %% [markdown]
# 4. Crea una gráfica que contenga dos líneas de diferente color, diferente grosor, y leyenda apropiada para cada línea
#
# <img
#   src="https://raw.githubusercontent.com/albreyes/python/d70737a223c6ce342ca2eafc2349d874d1e882b2/Grupo%20de%20python/notebooks/4-PythonDataScience/matplotlib/grafica_ejercicio_4.png"
#   alt="La cabeza y el torso de un esqueleto de dinosaurio;
#            tiene una cabeza grande con dientes largos y afilados"
#   width="400"
#   height="341" />

# %% [markdown]
# 5. Crea una gráfica que contenga dos líneas de diferente estilo
#
# <img
#   src="https://raw.githubusercontent.com/albreyes/python/d70737a223c6ce342ca2eafc2349d874d1e882b2/Grupo%20de%20python/notebooks/4-PythonDataScience/matplotlib/grafica_ejercicio_5.png"
#   alt="La cabeza y el torso de un esqueleto de dinosaurio;
#            tiene una cabeza grande con dientes largos y afilados"
#   width="400"
#   height="341" />

# %% [markdown]
# 6. Replica la siguiente gráfica
#
# <img
#   src="https://raw.githubusercontent.com/albreyes/python/d70737a223c6ce342ca2eafc2349d874d1e882b2/Grupo%20de%20python/notebooks/4-PythonDataScience/matplotlib/grafica_ejercicio_6.png"
#   alt="La cabeza y el torso de un esqueleto de dinosaurio;
#            tiene una cabeza grande con dientes largos y afilados"
#   width="400"
#   height="341" />

# %% [markdown]
# 7. Replica la siguiente gráfica utlizando los siguientes datos del valor de Alphabet Inc:
# ### Datos:
# **Date**|**Close**
# :-----:|:-----:
# 03-10-16|772.559998
# 04-10-16|776.429993
# 05-10-16|776.469971
# 06-10-16|776.859985
# 07-10-16|775.080017
#
# ### Gráfica
#
# <img
#   src="https://raw.githubusercontent.com/albreyes/python/d70737a223c6ce342ca2eafc2349d874d1e882b2/Grupo%20de%20python/notebooks/4-PythonDataScience/matplotlib/grafica_ejercicio_7.png"
#   alt="La cabeza y el torso de un esqueleto de dinosaurio;
#            tiene una cabeza grande con dientes largos y afilados"
#   width="400"
#   height="341" />

# %% [markdown]
# 8. Crea una gráfica de barras que muestre la popularidad de los lengaujes de programación:
# ### Datos:
# Lenguajes: Java, Python, PHP, JavaScript, C#, C++
#
# Popularidad: 22.2, 17.6, 8.8, 8, 7.7, 6.7
# ### Gráfica
#
# <img
#   src="https://raw.githubusercontent.com/albreyes/python/d70737a223c6ce342ca2eafc2349d874d1e882b2/Grupo%20de%20python/notebooks/4-PythonDataScience/matplotlib/grafica_ejercicio_8.png"
#   alt="La cabeza y el torso de un esqueleto de dinosaurio;
#            tiene una cabeza grande con dientes largos y afilados"
#   width="400"
#   height="341" />

# %% [markdown]
# 9. Repite la gráfica anterior pero con barras verdes horizontales
# ![]()
#
# <img
#   src="https://raw.githubusercontent.com/albreyes/python/d70737a223c6ce342ca2eafc2349d874d1e882b2/Grupo%20de%20python/notebooks/4-PythonDataScience/matplotlib/grafica_ejercicio_9.png"
#   alt="La cabeza y el torso de un esqueleto de dinosaurio;
#            tiene una cabeza grande con dientes largos y afilados"
#   width="400"
#   height="341" />

# %% [markdown]
# 10. Grafica la popularidad de los lenguajes de programación (mismos datos que el ejercicio 8), utilizando un color diferente para cada barra.
#
# <img
#   src="https://raw.githubusercontent.com/albreyes/python/d70737a223c6ce342ca2eafc2349d874d1e882b2/Grupo%20de%20python/notebooks/4-PythonDataScience/matplotlib/grafica_ejercicio_10.png"
#   alt="La cabeza y el torso de un esqueleto de dinosaurio;
#            tiene una cabeza grande con dientes largos y afilados"
#   width="400"
#   height="341" />
