# %% [markdown]
# <a href="https://colab.research.google.com/github/albreyes/python/blob/main/ejemploPreprocesamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Ejercicio: Limpieza y visualización de datos**

# %% [markdown]
# En este ejercicio usaremos pandas para preprocesar una una lista Billboard Hot 100 para posteriormente hacer un análisis visual sencillo con seaborn.
#
# La lista Billboard Hot 100 contiene información estándar de la industria musical en los Estados Unidos para canciones publicadas semanalmente por la revista Billboard. Su contenido se basa en las ventas, la reproducción de radio y la transmisión en línea en los Estados Unidos.
#
# Ejemplo obtenido desde [Billboard data](https://ift6758.github.io/lectures/billboard.html)

# %% [markdown]
# 1. Importe el conjunto de dato de billboard como un dataframe.

# %% [markdown]
# 2. Elimine las columnas con datos nulos (NAN o null)

# %% [markdown]
# 3. Revise si hay registros duplicados, y en su caso eliminelos.

# %% [markdown]
# 4. Elimine la columna *year* que siempre tiene el mis dato (2000)

# %% [markdown]
# 5. Ahora use *seaborn* para hacer el anlisis visual del conjunto de datos limpio. Primero, haga un análisis de frecuencias por registro utilizando un historama para la columna *x1st.week*.

# %% [markdown]
# 6. Haga una gráfica de conteo para la columna *genre* (o género)

# %% [markdown]
# 7. Para una mejor perspectiva, rote la gráfica de modo que el eje X sea ahora el Y.

# %%
#sb.countplot(y='artist.inverted',data=temporal);
sb.countplot(y='genre',data=temporal);
